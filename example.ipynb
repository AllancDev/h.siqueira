# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
with open("example.txt", "r") as example:
    data = example.read()

# %%
graph = data.split('\n')

G = nx.Graph()


for x in graph: 
    a = x.split(' ')
    G.add_edge(str(a[0]), str(a[1]), weight=int(a[2]))

labels = nx.get_edge_attributes(G,'weight')

pos=nx.spring_layout(G)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

nx.draw(G, with_labels=True, font_color="white", horizontalalignment='center', verticalalignment='bottom')

plt.show()

origem = input("Por favor digite a origem: ")
destino = input("Por favor digite a destino: ")

pos=nx.spring_layout(G)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels, horizontalalignment='bottom', verticalalignment='center')

path = nx.shortest_path(G, source=origem, target=destino)
nx.draw(G, with_labels=True, nodelist=path, node_color='#a74141', font_color="white")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 15>()
#      12 pos=nx.spring_layout(G)
#      13 nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# ---> 15 nx.draw(G, with_labels=True, font_color="white", horizontalalignment='bottom', verticalalignment='center')
#      17 plt.show()
#      19 origem = input("Por favor digite a origem: ")
#
# File ~/workspace/h.siqueira/venv/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py:121, in draw(G, pos, ax, **kwds)
#     118 if "with_labels" not in kwds:
#     119     kwds["with_labels"] = "labels" in kwds
# --> 121 draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122 ax.set_axis_off()
#     123 plt.draw_if_interactive()
#
# File ~/workspace/h.siqueira/venv/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py:306, in draw_networkx(G, pos, arrows, with_labels, **kwds)
# ...
